# %%
import numpy as np 
import pandas as pd

# %%
movies=pd.read_csv('/kaggle/input/tmdb-movies-dataset-2023-930k-movies/TMDB_movie_dataset_v11.csv')

# %%
print(movies.head())
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# 0        Inception  Cobb, a skilled thief who commits corporate es...
# 1     Interstellar  The adventures of a group of explorers who mak...
# 2  The Dark Knight  Batman raises the stakes in his war on crime. ...
# 3           Avatar  In the 22nd century, a paraplegic Marine is di...
# 4     The Avengers  When an unexpected enemy emerges and threatens...
#
#   popularity                       poster_path  \
# 0     83.952  /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1    140.241  /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2    130.643  /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3     79.932  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4     98.082   /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
#
#                                              tagline  \
# 0               Your mind is the scene of the crime.
# 1  Mankind was born on Earth. It was never meant ...
# 2                  Welcome to a world without rules.
# 3                        Enter the world of Pandora.
# 4                            Some assembly required.
#
#                                         genres  \
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2  DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3  Dune Entertainment, Lightstorm Entertainment, ...
# 4                                     Marvel Studios
#
#                        production_countries  \
# 0  United Kingdom, United States of America
# 1  United Kingdom, United States of America
# 2  United Kingdom, United States of America
# 3  United States of America, United Kingdom
# 4                  United States of America
#
#                      spoken_languages  \
# 0  English, French, Japanese, Swahili
# 1                             English
# 2                   English, Mandarin
# 3                    English, Spanish
# 4             English, Hindi, Russian
#
#                                             keywords
# 0  rescue, mission, dream, airplane, paris, franc...
# 1  rescue, future, spacecraft, race against time,...
# 2  joker, sadism, chaos, secret identity, crime f...
# 3  future, society, culture clash, space travel, ...
# 4  new york city, superhero, shield, based on com...
#
# [5 rows x 24 columns]

# %%
movies.dropna(subset=['title'], inplace=True)
#movies.dropna(subset=['release_date'], inplace=True)
movies.dropna(subset=['overview'], inplace=True)
movies.dropna(subset=['genres'], inplace=True)

# %%
print(movies.isna().sum())
# Out:
# id                           0
# title                        0
# vote_average                 0
# vote_count                   0
# status                       0
# release_date             26783
# revenue                      0
# runtime                      0
# adult                        0
# backdrop_path           336438
# budget                       0
# homepage                466558
# imdb_id                 158083
# original_language            0
# original_title               0
# overview                     0
# popularity                   0
# poster_path             105824
# tagline                 435753
# genres                       0
# production_companies    218485
# production_countries    134322
# spoken_languages        125534
# keywords                332835
# dtype: int64

# %%
movies['release_date'] = pd.to_datetime(movies['release_date'], errors='coerce')

# %%
movies['year'] = movies['release_date'].dt.year

# %%
movies.head(1)
# Out:
#       id      title  vote_average  vote_count    status release_date  \
# 0  27205  Inception         8.364       34495  Released   2010-07-15
#
#      revenue  runtime  adult                     backdrop_path  ...  \
# 0  825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
#
#                                             overview popularity  \
# 0  Cobb, a skilled thief who commits corporate es...     83.952
#
#                         poster_path                               tagline  \
# 0  /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg  Your mind is the scene of the crime.
#
#                                genres  \
# 0  Action, Science Fiction, Adventure
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
#
#                        production_countries  \
# 0  United Kingdom, United States of America
#
#                      spoken_languages  \
# 0  English, French, Japanese, Swahili
#
#                                             keywords    year
# 0  rescue, mission, dream, airplane, paris, franc...  2010.0
#
# [1 rows x 25 columns]

# %%
latest_movies = movies[movies['year'] >= 2023].reset_index(drop=True)

# %%
latest_movies.shape
# Out:
# (32918, 25)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


tfidf = TfidfVectorizer(stop_words='english')


latest_movies['overview'] = latest_movies['overview'].fillna('')


tfidf_matrix = tfidf.fit_transform(latest_movies['overview'])


tfidf_matrix.shape
# Out:
# (32918, 57107)

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
cosine_sim
# Out:
# array([[1.        , 0.01932927, 0.        , ..., 0.0060826 , 0.02296331,
#         0.        ],
#        [0.01932927, 1.        , 0.        , ..., 0.0109984 , 0.0155332 ,
#         0.        ],
#        [0.        , 0.        , 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.0060826 , 0.0109984 , 0.        , ..., 1.        , 0.00874695,
#         0.00611335],
#        [0.02296331, 0.0155332 , 0.        , ..., 0.00874695, 1.        ,
#         0.00600496],
#        [0.        , 0.        , 0.        , ..., 0.00611335, 0.00600496,
#         1.        ]])

# %%
indices = pd.Series(latest_movies.index, index=latest_movies['title']).drop_duplicates()

# %%
indices
# Out:
# title
# The Super Mario Bros. Movie                0
# Barbie                                     1
# Guardians of the Galaxy Vol. 3             2
# John Wick: Chapter 4                       3
# Spider-Man: Across the Spider-Verse        4
#                                        ...
# Ardhangini                             32913
# Negative Numbers                       32914
# Невидимый мой                          32915
# Moon Beams                             32916
# Teresa                                 32917
# Length: 32918, dtype: int64

# %%
def get_recommendations(title, cosine_sim=cosine_sim):
   
    idx_series = indices.get(title)

    
    if idx_series is None:
        return f"Movie title '{title}' not found in the dataset."
    
    
    if isinstance(idx_series, pd.Series):
        indices_list = idx_series.tolist()
    else:
        indices_list = [idx_series]

    
    all_recommendations = []
    for idx in indices_list:
        
        sim_scores = [(i, cosine_sim[idx, i].item()) for i in range(len(cosine_sim))]

       
        sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

        
        sim_scores = sim_scores[1:11]

        
        movie_indices = [i[0] for i in sim_scores]

        
        all_recommendations.append(latest_movies['title'].iloc[movie_indices].tolist())

    return all_recommendations

# %%
latest_movies
# Out:
#            id                                title  vote_average  vote_count  \
# 0      502356          The Super Mario Bros. Movie         7.775        6743
# 1      346698                               Barbie         7.279        5074
# 2      447365       Guardians of the Galaxy Vol. 3         8.023        4941
# 3      603692                 John Wick: Chapter 4         7.814        4639
# 4      569094  Spider-Man: Across the Spider-Verse         8.442        4394
# ...       ...                                  ...           ...         ...
# 32913  716373                           Ardhangini         0.000           0
# 32914  701393                     Negative Numbers         0.000           0
# 32915  707960                        Невидимый мой         0.000           0
# 32916  708415                           Moon Beams         0.000           0
# 32917  710157                               Teresa         0.000           0
#
#                 status release_date     revenue  runtime  adult  \
# 0             Released   2023-04-05  1355725263       93  False
# 1             Released   2023-07-19  1428545028      114  False
# 2             Released   2023-05-03   845430302      150  False
# 3             Released   2023-03-22   426978565      170  False
# 4             Released   2023-05-31   683241751      140  False
# ...                ...          ...         ...      ...    ...
# 32913         Released   2023-06-02           0      135  False
# 32914         Released   2023-10-04           0       93  False
# 32915    In Production   2023-10-06           0      102  False
# 32916  Post Production   2023-11-03           0        0  False
# 32917          Planned   2023-11-24           0        0  False
#
#                           backdrop_path  ...  \
# 0      /9n2tJBplPbgR2ca05hS5CKXwP2c.jpg  ...
# 1      /ctMserH8g2SeOAnCw5gFjdQF8mo.jpg  ...
# 2      /5YZbUmjbMa3ClvSW1Wj3D6XGolb.jpg  ...
# 3      /i3OTGmLNOZIo4SRQLVfLjeWegB6.jpg  ...
# 4      /4HodYYKEIsGOdinkGi2Ucz6X9i0.jpg  ...
# ...                                 ...  ...
# 32913                               NaN  ...
# 32914  /muXS6AlYcaRFz44ABIl9hp5eRJF.jpg  ...
# 32915                               NaN  ...
# 32916  /hdri42Dt3xK3tu5CS8KNS6MYbVt.jpg  ...
# 32917                               NaN  ...
#
#                                                 overview popularity  \
# 0      While working underground to fix a water main,...    410.411
# 1      Barbie and Ken are having the time of their li...   1069.340
# 2      Peter Quill, still reeling from the loss of Ga...    318.516
# 3      With the price on his head ever increasing, Jo...    482.538
# 4      After reuniting with Gwen Stacy, Brooklyn’s fu...    512.336
# ...                                                  ...        ...
# 32913  After Suman suffers an accident, the two women...      1.714
# 32914  "Negative Numbers" is the true story of a juve...      8.221
# 32915  Single mother Maria (Daria Ekamasova) lives wi...      4.866
# 32916  While on the run after killing a cop, drug dea...      1.913
# 32917  The plot follows the dialectic duel between my...      1.623
#
#                             poster_path  \
# 0      /qNBAXBIQlnOThrVvA6mA2B5ggV6.jpg
# 1      /iuFNMS8U5cb6xfzi51Dbkovj7vM.jpg
# 2      /r2J02Z2OpNTctfOSN1Ydgii51I3.jpg
# 3       /vZloFAK7NmvMGKE7VkF5UHaz0I.jpg
# 4      /8Vt6mWEReuy4Of61Lnj5Xj704m8.jpg
# ...                                 ...
# 32913  /hmglpFovmhStKBdV32HCJ5W08Q0.jpg
# 32914  /8XiIEGWb0AM7cVjgi5vZQ2PAU22.jpg
# 32915                               NaN
# 32916  /cHuK99oSKvzYNof9DxKG4ZUDk3t.jpg
# 32917  /m0cXFWYXpAzFtG5L98OOxhx2F3z.jpg
#
#                                               tagline  \
# 0      Not all heroes wear capes. Some wear overalls.
# 1                    She's everything. He's just Ken.
# 2                             Once more with feeling.
# 3                           No way back, one way out.
# 4            It's how you wear the mask that matters.
# ...                                               ...
# 32913                                             NaN
# 32914                            BASED ON REAL EVENTS
# 32915                                             NaN
# 32916                        People change overnight.
# 32917                                             NaN
#
#                                               genres  \
# 0      Animation, Family, Adventure, Fantasy, Comedy
# 1                         Comedy, Adventure, Fantasy
# 2                 Science Fiction, Adventure, Action
# 3                            Action, Thriller, Crime
# 4                       Animation, Action, Adventure
# ...                                              ...
# 32913                         Romance, Family, Drama
# 32914                                          Drama
# 32915                                          Drama
# 32916                       Crime, Thriller, Romance
# 32917                                          Drama
#
#                                     production_companies  \
# 0             Universal Pictures, Illumination, Nintendo
# 1      LuckyChap Entertainment, Heyday Films, NB/GG P...
# 2                Marvel Studios, Kevin Feige Productions
# 3      Thunder Road, 87Eleven, Summit Entertainment, ...
# 4      Columbia Pictures, Sony Pictures Animation, Lo...
# ...                                                  ...
# 32913                                     Surinder Films
# 32914  Magnet Films, Alief, 1991 Productions, Wide Ma...
# 32915                                                NaN
# 32916                                 Coffee Whale Films
# 32917                       Bluebird Films, Inicia Films
#
#                            production_countries  \
# 0               Japan, United States of America
# 1      United Kingdom, United States of America
# 2                      United States of America
# 3             Germany, United States of America
# 4                      United States of America
# ...                                         ...
# 32913                                     India
# 32914                    France, Georgia, Italy
# 32915                                    Russia
# 32916                                       NaN
# 32917                            Belgium, Spain
#
#                                         spoken_languages  \
# 0                                                English
# 1                                                English
# 2                                                English
# 3      Arabic, Cantonese, English, French, German, Ja...
# 4                       English, Hindi, Italian, Spanish
# ...                                                  ...
# 32913                                            Bengali
# 32914                                           Georgian
# 32915                                            Russian
# 32916                                            English
# 32917                                            Spanish
#
#                                                 keywords    year
# 0      gorilla, plumber, anthropomorphism, magic mush...  2023.0
# 1      feminism, satire, patriarchy, based on toy, fe...  2023.0
# 2      hero, superhero, mad scientist, based on comic...  2023.0
# 3      new york city, martial arts, hitman, sequel, o...  2023.0
# 4      new york city, sacrifice, superhero, comic boo...  2023.0
# ...                                                  ...     ...
# 32913                                                NaN  2023.0
# 32914                                                NaN  2023.0
# 32915                                                NaN  2023.0
# 32916                                                NaN  2023.0
# 32917                   based on play or musical, biopic  2023.0
#
# [32918 rows x 25 columns]

# %%
idx = indices['John Wick: Chapter 4']
print("Movie:", idx)
# Out:
# Movie: 3

# %%
get_recommendations("Barbie")
# Out:
# [['Barbie',
#   'Barbie 2',
#   'My First Barbie: Happy DreamDay',
#   "Barbie 2: Ken's Revenge",
#   'JUST KEN',
#   'Barbie: The Perfect Woman?',
#   'Love, In Color',
#   'Anti-Human Rhapsody',
#   'Bad Barbie',
#   'Springtime in Amsterdam'],
#  ['Barbie 2',
#   'My First Barbie: Happy DreamDay',
#   "Barbie 2: Ken's Revenge",
#   'Barbie',
#   'Die Hart 2',
#   'Permanent Derealizer',
#   'How Do I Look?',
#   'In My Own Time',
#   'JUST KEN',
#   'Barbie: The Perfect Woman?']]

# %%
latest_movies[['genres','production_companies']].head(3)
# Out:
#                                           genres  \
# 0  Animation, Family, Adventure, Fantasy, Comedy
# 1                     Comedy, Adventure, Fantasy
# 2             Science Fiction, Adventure, Action
#
#                                 production_companies
# 0         Universal Pictures, Illumination, Nintendo
# 1  LuckyChap Entertainment, Heyday Films, NB/GG P...
# 2            Marvel Studios, Kevin Feige Productions

# %%
latest_movies.columns
# Out:
# Index(['id', 'title', 'vote_average', 'vote_count', 'status', 'release_date',
#        'revenue', 'runtime', 'adult', 'backdrop_path', 'budget', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'tagline', 'genres',
#        'production_companies', 'production_countries', 'spoken_languages',
#        'keywords', 'year'],
#       dtype='object')

# %%
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
        
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return ''

# %%
features=['production_companies','genres']
for x in features:
    latest_movies[x] = latest_movies[x].apply(clean_data)

# %%
latest_movies[['production_companies','genres']].head()
# Out:
#                                 production_companies  \
# 0            universalpictures,illumination,nintendo
# 1  luckychapentertainment,heydayfilms,nb/ggpictur...
# 2                marvelstudios,kevinfeigeproductions
# 3  thunderroad,87eleven,summitentertainment,studi...
# 4  columbiapictures,sonypicturesanimation,lordmil...
#
#                                       genres
# 0  animation,family,adventure,fantasy,comedy
# 1                   comedy,adventure,fantasy
# 2            sciencefiction,adventure,action
# 3                      action,thriller,crime
# 4                 animation,action,adventure

# %%
latest_movies['soup'] = latest_movies['production_companies'].fillna('') + ' ' + latest_movies['genres'].fillna('') + ' ' + latest_movies['overview'].fillna('')


latest_movies['soup'] = latest_movies['soup'].fillna('')

# %%
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(latest_movies['soup'])

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim2 = cosine_similarity(count_matrix, count_matrix)

# %%
indices2 = pd.Series(latest_movies.index, index=latest_movies['title']).drop_duplicates()

# %%
get_recommendations('Spider-Man: Across the Spider-Verse', cosine_sim2)
# Out:
# [['Enter The Spider-Verse: A Spider-Man Special',
#   'Spider-Man: RAF',
#   'Spider-Man: Date Night',
#   'Spider-Man & The Spider-Verse Revolution (To Be Continued)',
#   'Shin Spider-Man',
#   'Lemon man vs the Multiverse',
#   'Harry’s Brainrot(The Complete Trilogy)',
#   'Spin & Ella',
#   'Spider-Man: Lotus',
#   'Homemade Into the Spider-Verse']]
